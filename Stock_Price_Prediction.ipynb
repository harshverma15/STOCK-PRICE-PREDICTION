# %% [markdown]
# # ***IMPORTING LIBRARIES AND UPLOADING DATASETS***

# %%
import statistics
import numpy as np
import pandas as pd
import seaborn as sns
import math
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
import seaborn as sns
from datetime import datetime

# %% [markdown]
# Here we have used upload function of files from google colab library for uploading our datasets

# %%
from google.colab import files
uploaded1 = files.upload()
uploaded2 = files.upload()
uploaded3 = files.upload()
# Out:
#      <input type="file" id="files-6a6f99d9-0ef7-4b2d-8c90-d73d90356511" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a6f99d9-0ef7-4b2d-8c90-d73d90356511">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # ***BASIC OPERATIONS***

# %% [markdown]
# Here we are using pandas to read the csv files

# %%
drrdy = pd.read_csv("DRREDDY.csv")
drrdy2 = pd.read_csv("DRREDDY.csv", index_col=1)
hcl = pd.read_csv("HCLTECH.csv")
hcl2 = pd.read_csv("HCLTECH.csv", index_col=1)
tcsdf = pd.read_csv("TCS.csv")
tcsdf2 = pd.read_csv("TCS.csv", index_col=1)
tcsdf['Year'] = tcsdf['Date'].apply(func=lambda string:datetime.strptime(string, "%Y-%m-%d").strftime("%Y"))
hcl['Year'] = hcl['Date'].apply(func=lambda string:datetime.strptime(string, "%Y-%m-%d").strftime("%Y")) 
drrdy['Year'] = drrdy['Date'].apply(func=lambda string:datetime.strptime(string, "%Y-%m-%d").strftime("%Y"))

# %% [markdown]
# Here we are using the info function of pandas for printing a concise summary of our dataframe

# %%
drrdy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   object
#  1   Symbol              5306 non-null   object
#  2   Series              5306 non-null   object
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4797 non-null   float64
#  14  %Deliverble         4797 non-null   float64
# ...

# %%
drrdy
# Out:
#             Date   Symbol Series  Prev Close     Open     High      Low  \
# 0     2000-01-03  DRREDDY     EQ     1396.50  1505.00  1508.25  1505.00
# 1     2000-01-04  DRREDDY     EQ     1508.25  1590.00  1628.95  1510.00
# 2     2000-01-05  DRREDDY     EQ     1628.95  1549.00  1650.00  1499.00
# 3     2000-01-06  DRREDDY     EQ     1568.05  1599.00  1693.50  1571.00
# 4     2000-01-07  DRREDDY     EQ     1661.55  1685.00  1685.00  1528.65
# ...          ...      ...    ...         ...      ...      ...      ...
# 5301  2021-04-26  DRREDDY     EQ     5066.70  5125.00  5130.00  5030.25
# 5302  2021-04-27  DRREDDY     EQ     5066.70  5090.50  5116.00  5021.35
# 5303  2021-04-28  DRREDDY     EQ     5057.25  5082.55  5106.90  5030.00
# 5304  2021-04-29  DRREDDY     EQ     5044.45  5070.25  5144.00  5042.30
# 5305  2021-04-30  DRREDDY     EQ     5102.30  5140.00  5211.00  5125.15
#
#          Last    Close     VWAP   Volume      Turnover   Trades  \
# ...

# %% [markdown]
# Here we are using two function of pandas i.e. isnull and sum. We are using isnull to check if their is a null value present in the column it returns true else false and the sum function adds 1 to the sum of the column if true is returned from the isnull function. So, basically this line if finding the sum of the null values present in each column

# %%
drrdy.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     509
# %Deliverble            509
# Year                     0
# dtype: int64

# %%
hcl
# Out:
#             Date   Symbol Series  Prev Close    Open     High      Low  \
# 0     2000-01-11  HCLTECH     EQ      580.00  1550.0  1725.00  1492.00
# 1     2000-01-12  HCLTECH     EQ     1554.45  1560.0  1678.85  1560.00
# 2     2000-01-13  HCLTECH     EQ     1678.85  1790.0  1813.20  1781.00
# 3     2000-01-14  HCLTECH     EQ     1813.20  1958.3  1958.30  1835.00
# 4     2000-01-17  HCLTECH     EQ     1958.30  2115.0  2115.00  1801.65
# ...          ...      ...    ...         ...     ...      ...      ...
# 5295  2021-04-26  HCLTECH     EQ      955.65   940.0   954.50   923.05
# 5296  2021-04-27  HCLTECH     EQ      928.80   931.0   938.55   923.40
# 5297  2021-04-28  HCLTECH     EQ      928.85   931.2   935.85   921.75
# 5298  2021-04-29  HCLTECH     EQ      923.80   929.7   929.70   907.10
# 5299  2021-04-30  HCLTECH     EQ      909.55   905.0   915.00   895.40
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %%
hcl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5300 entries, 0 to 5299
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5300 non-null   object
#  1   Symbol              5300 non-null   object
#  2   Series              5300 non-null   object
#  3   Prev Close          5300 non-null   float64
#  4   Open                5300 non-null   float64
#  5   High                5300 non-null   float64
#  6   Low                 5300 non-null   float64
#  7   Last                5300 non-null   float64
#  8   Close               5300 non-null   float64
#  9   VWAP                5300 non-null   float64
#  10  Volume              5300 non-null   int64
#  11  Turnover            5300 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4797 non-null   float64
#  14  %Deliverble         4797 non-null   float64
# ...

# %%
hcl.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2844
# Deliverable Volume     503
# %Deliverble            503
# Year                     0
# dtype: int64

# %%
tcsdf
# Out:
#             Date Symbol Series  Prev Close     Open     High      Low  \
# 0     2004-08-25    TCS     EQ      850.00  1198.70  1198.70   979.00
# 1     2004-08-26    TCS     EQ      987.95   992.00   997.00   975.30
# 2     2004-08-27    TCS     EQ      979.00   982.40   982.40   958.55
# 3     2004-08-30    TCS     EQ      962.65   969.90   990.00   965.00
# 4     2004-08-31    TCS     EQ      986.75   986.50   990.00   976.00
# ...          ...    ...    ...         ...      ...      ...      ...
# 4134  2021-04-26    TCS     EQ     3109.50  3102.05  3153.00  3088.05
# 4135  2021-04-27    TCS     EQ     3100.80  3106.00  3136.10  3103.00
# 4136  2021-04-28    TCS     EQ     3132.00  3149.95  3151.00  3112.00
# 4137  2021-04-29    TCS     EQ     3124.10  3145.60  3157.35  3105.50
# 4138  2021-04-30    TCS     EQ     3115.25  3099.00  3132.05  3020.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %%
tcsdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4139 entries, 0 to 4138
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                4139 non-null   object
#  1   Symbol              4139 non-null   object
#  2   Series              4139 non-null   object
#  3   Prev Close          4139 non-null   float64
#  4   Open                4139 non-null   float64
#  5   High                4139 non-null   float64
#  6   Low                 4139 non-null   float64
#  7   Last                4139 non-null   float64
#  8   Close               4139 non-null   float64
#  9   VWAP                4139 non-null   float64
#  10  Volume              4139 non-null   int64
#  11  Turnover            4139 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4139 non-null   int64
#  14  %Deliverble         4139 non-null   float64
# ...

# %%
tcsdf.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                1683
# Deliverable Volume       0
# %Deliverble              0
# Year                     0
# dtype: int64

# %% [markdown]
# Here we are using describe function of pandas to calculate mean, standard deviation, minimum, 25%, 50%, 75% and maximum of every column in the dataset

# %%
drrdy.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean   1827.672814  1830.099821  1855.226715  1803.185488  1828.279693
# std    1092.984492  1095.534718  1106.531082  1082.903924  1093.978015
# min     374.000000   365.650000   384.950000   355.250000   375.150000
# 25%     906.175000   908.175000   923.175000   897.000000   906.125000
# 50%    1538.825000  1539.500000  1565.375000  1511.125000  1539.000000
# 75%    2609.337500  2612.000000  2641.500000  2582.900000  2609.812500
# max    5416.800000  5440.950000  5512.650000  5329.450000  5413.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03    2456.000000
# mean   1828.382689  1829.621266  4.409815e+05  1.045022e+14   37121.187296
# std    1093.927165  1094.668053  6.060398e+05  2.719076e+14   39213.885661
# ...

# %%
hcl.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5300.000000  5300.000000  5300.000000  5300.000000  5300.000000
# mean    642.113802   643.018887   654.269217   630.466274   642.240547
# std     411.660337   413.208429   420.237830   404.336086   411.739377
# min      89.700000    87.100000    94.750000    86.650000    89.000000
# 25%     314.200000   315.825000   322.725000   308.050000   314.462500
# 50%     535.075000   533.250000   545.000000   520.250000   535.150000
# 75%     893.975000   893.425000   907.837500   882.487500   895.425000
# max    2819.150000  2825.000000  2998.000000  2760.500000  2805.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  5300.000000  5300.000000  5.300000e+03  5.300000e+03    2456.000000
# mean    642.173981   642.502587  1.645121e+06  1.075213e+14   65378.973941
# std     411.674568   412.001186  2.187826e+06  1.718074e+14   47842.804142
# ...

# %%
tcsdf.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  4139.000000  4139.000000  4139.000000  4139.000000  4139.000000
# mean   1693.843549  1695.594081  1715.882302  1673.585709  1694.310184
# std     722.879316   722.978228   728.450096   717.780248   723.177934
# min     366.650000   360.000000   377.750000   358.000000   365.700000
# 25%    1106.250000  1105.525000  1120.275000  1088.575000  1107.000000
# 50%    1633.500000  1625.000000  1655.000000  1610.000000  1630.050000
# 75%    2326.125000  2321.800000  2345.000000  2301.300000  2325.000000
# max    3603.700000  3625.000000  3674.800000  3572.550000  3610.750000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  4139.000000  4139.000000  4.139000e+03  4.139000e+03    2456.000000
# mean   1694.371612  1694.618120  1.676762e+06  2.952102e+14   85502.709283
# std     723.061025   723.144157  1.607879e+06  3.849370e+14   56031.488595
# ...

# %%
drrdy['Total traded'] = ""
drrdy['Total traded']=drrdy['Volume']
drrdy
# Out:
#             Date   Symbol Series  Prev Close     Open     High      Low  \
# 0     2000-01-03  DRREDDY     EQ     1396.50  1505.00  1508.25  1505.00
# 1     2000-01-04  DRREDDY     EQ     1508.25  1590.00  1628.95  1510.00
# 2     2000-01-05  DRREDDY     EQ     1628.95  1549.00  1650.00  1499.00
# 3     2000-01-06  DRREDDY     EQ     1568.05  1599.00  1693.50  1571.00
# 4     2000-01-07  DRREDDY     EQ     1661.55  1685.00  1685.00  1528.65
# ...          ...      ...    ...         ...      ...      ...      ...
# 5301  2021-04-26  DRREDDY     EQ     5066.70  5125.00  5130.00  5030.25
# 5302  2021-04-27  DRREDDY     EQ     5066.70  5090.50  5116.00  5021.35
# 5303  2021-04-28  DRREDDY     EQ     5057.25  5082.55  5106.90  5030.00
# 5304  2021-04-29  DRREDDY     EQ     5044.45  5070.25  5144.00  5042.30
# 5305  2021-04-30  DRREDDY     EQ     5102.30  5140.00  5211.00  5125.15
#
#          Last    Close     VWAP   Volume      Turnover   Trades  \
# ...

# %%
hcl['Total traded'] = ""
hcl['Total traded']=hcl['Volume']
hcl
# Out:
#             Date   Symbol Series  Prev Close    Open     High      Low  \
# 0     2000-01-11  HCLTECH     EQ      580.00  1550.0  1725.00  1492.00
# 1     2000-01-12  HCLTECH     EQ     1554.45  1560.0  1678.85  1560.00
# 2     2000-01-13  HCLTECH     EQ     1678.85  1790.0  1813.20  1781.00
# 3     2000-01-14  HCLTECH     EQ     1813.20  1958.3  1958.30  1835.00
# 4     2000-01-17  HCLTECH     EQ     1958.30  2115.0  2115.00  1801.65
# ...          ...      ...    ...         ...     ...      ...      ...
# 5295  2021-04-26  HCLTECH     EQ      955.65   940.0   954.50   923.05
# 5296  2021-04-27  HCLTECH     EQ      928.80   931.0   938.55   923.40
# 5297  2021-04-28  HCLTECH     EQ      928.85   931.2   935.85   921.75
# 5298  2021-04-29  HCLTECH     EQ      923.80   929.7   929.70   907.10
# 5299  2021-04-30  HCLTECH     EQ      909.55   905.0   915.00   895.40
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %%
tcsdf['Total traded'] = ""
tcsdf['Total traded']=tcsdf['Volume']
tcsdf
# Out:
#             Date Symbol Series  Prev Close     Open     High      Low  \
# 0     2004-08-25    TCS     EQ      850.00  1198.70  1198.70   979.00
# 1     2004-08-26    TCS     EQ      987.95   992.00   997.00   975.30
# 2     2004-08-27    TCS     EQ      979.00   982.40   982.40   958.55
# 3     2004-08-30    TCS     EQ      962.65   969.90   990.00   965.00
# 4     2004-08-31    TCS     EQ      986.75   986.50   990.00   976.00
# ...          ...    ...    ...         ...      ...      ...      ...
# 4134  2021-04-26    TCS     EQ     3109.50  3102.05  3153.00  3088.05
# 4135  2021-04-27    TCS     EQ     3100.80  3106.00  3136.10  3103.00
# 4136  2021-04-28    TCS     EQ     3132.00  3149.95  3151.00  3112.00
# 4137  2021-04-29    TCS     EQ     3124.10  3145.60  3157.35  3105.50
# 4138  2021-04-30    TCS     EQ     3115.25  3099.00  3132.05  3020.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %% [markdown]
# Here we are using MATPLOTLIP.PYPLOT to plot a graph for comparing the total traded stocks

# %%
drrdy['Total traded'].plot(label = 'DRREDDY', figsize= (16,8))
hcl['Total traded'].plot(label = 'HCL TECH', figsize=(16,8))
tcsdf['Total traded'].plot(label = 'TCS', figsize=(16,8))
plt.title('COMPARISON OF TOTAL TRADED')
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.legend()

maxdr = drrdy['Total traded'].max()
print('Maximum of DRREDDY total traded stocks in a day', maxdr)
maxhcl = hcl['Total traded'].max()
print('Maximum of HCLTECH total traded stocks in a day', maxhcl)
maxtcs = tcsdf['Total traded'].max()
print('Maximum of TCS total traded stocks in a day', maxtcs)
maxlst = [maxdr, maxhcl, maxtcs]
mx = (maxdr if (maxdr > maxhcl and maxdr > maxtcs) else
     (maxhcl if (maxhcl > maxdr and maxhcl > maxtcs) else maxtcs))
if mx == maxdr:
  print('DRREDDY stocks have been traded the most in a day')
if mx == maxhcl:
  print("HCLTECH stocks have been traded the most in a day")
if mx == maxtcs:
  print("TCS stocks have been traded the most in a day")
# Out:
# Maximum of DRREDDY total traded stocks in a day 21987146
# Maximum of HCLTECH total traded stocks in a day 32312531
# Maximum of TCS total traded stocks in a day 44033577
# TCS stocks have been traded the most in a day

# %%
drrdy["Close"].plot(label = 'DRREDDY',figsize = (16,8))
hcl["Close"].plot(label = 'HCL', figsize = (16,8))
tcsdf["Close"].plot(label = 'TCS',figsize = (16,8))
plt.title('COMPARISON OF CLOSING COST')
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.legend()

maxcldr = drrdy['Close'].max()
print('Maximum closing cost attained by DRREDDY in a day', maxcldr)
maxclhcl = hcl['Close'].max()
print('Maximum closing cost attained by HCLTECH in a day', maxclhcl)
maxcltcs = tcsdf['Close'].max()
print('Maximum closing cost attained by TCS in a day', maxcltcs)


mx = (maxcldr if (maxcldr > maxclhcl and maxcldr > maxcltcs) else
     (maxclhcl if (maxclhcl > maxcldr and maxclhcl > maxcltcs) else maxcltcs))
if mx == maxcldr:
  print('DRREDDY has attained the highest closing cost in a day')
if mx == maxclhcl:
  print('HCLTECH has attained the highest closing cost in a day')
if mx == maxcltcs:
  print('TCS has attained the highest closing cost in a day')
# Out:
# Maximum closing cost attained by DRREDDY in a day 5416.8
# Maximum closing cost attained by HCLTECH in a day 2819.15
# Maximum closing cost attained by TCS in a day 3603.7
# DRREDDY has attained the highest closing cost in a day

# %% [markdown]
# # ***PLOT FOR THE MOVING AVERAGES***

# %% [markdown]
# Here we have used tow function of pandas rolling and mean, where rolling defines the window for which the mean is to be calculated.

# %%
drrdy['MA1']=""
drrdy['MA2']=""
hcl['MA1']=""
hcl['MA2']=""
tcsdf['MA1']=""
tcsdf['MA2']=""



drrdy['MA1'] = drrdy['Open'].rolling(50).mean()
drrdy['MA2'] = drrdy['Open'].rolling(200).mean()
drrdy[['Open','MA1','MA2']].plot(label = 'DRREDDY', figsize=(16,10));
plt.title('DRREDDY MOVING AVERAGES')

hcl['MA1'] = hcl['Open'].rolling(50).mean()
hcl['MA2'] = hcl['Open'].rolling(200).mean()
hcl[['Open','MA1','MA2']].plot(label = 'HCL TECH', figsize=(16,10));
plt.title('HCL TECH MOVING AVERAGES')

tcsdf['MA1'] = tcsdf['Open'].rolling(50).mean()
tcsdf['MA2'] = tcsdf['Open'].rolling(200).mean()
tcsdf[['Open','MA1','MA2']].plot(label = 'TCS', figsize=(16,10));
plt.title('TCS MOVING AVERAGES')
# Out:
# Text(0.5, 1.0, 'TCS MOVING AVERAGES')

# %% [markdown]
# **MOVING AVERAGES PLOT BASED UPON USERS CHOICE**

# %%
stock = input("Enter the name of stock fow which you want moving averages: ")
n = int(input('Enter the year for which you want a graph of moving averages: '))
ma1 = int(input('Enter the number of days for which you want moving average '))
print(tcsdf.columns)

if(stock == 'DRREDDY'):
  drrdy['MA1'] = drrdy['Open'].rolling(50).mean()
  drrdy['MA2'] = drrdy['Open'].rolling(200).mean()
  drrdy[['Open','MA1','MA2']].plot(label = 'DRREDDY', figsize=(16,10));
  plt.title('DRREDDY MOVING AVERAGES')
if(stock == 'HCLTECH'):
  hcl['MA1'] = hcl['Open'].rolling(50).mean()
  hcl['MA2'] = hcl['Open'].rolling(200).mean()
  hcl[['Open','MA1','MA2']].plot(label = 'HCL TECH', figsize=(16,10));
  plt.title('HCL TECH MOVING AVERAGES')
if(stock == 'TCS'):
  tcsdf['MA1'] = tcsdf['Open'].rolling(50).mean()
  tcsdf['MA2'] = tcsdf['Open'].rolling(200).mean()  
  tcsdf[['Open','MA1','MA2']].plot(label = 'TCS', figsize=(16,10));
  plt.title('TCS MOVING AVERAGES')
# Out:
# Enter the name of stock fow which you want moving averages: HCLTECH
# Enter the year for which you want a graph of moving averages: 2004
# Enter the number of days for which you want moving average 50
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble', 'Year', 'Total traded', 'MA1', 'MA2'],
#       dtype='object')

# %%
import plotly.graph_objects as go
import datetime
print("Candlestick graph for DR REDDY")
drrdy2=drrdy2.set_index(pd.DatetimeIndex(drrdy2['Date']))
fig = go.Figure(data=[go.Candlestick(x=drrdy2.index,
                open=drrdy['Open'],
                high=drrdy['High'],
                low=drrdy['Low'],
                close=drrdy['Close'],
                increasing_line_color='green',
                decreasing_line_color='red')])


fig.show()
# Out:
# Candlestick graph for DR REDDY
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# CANDLESTICK GRAPH FOR HCLTECH

# %%
hcl2=hcl2.set_index(pd.DatetimeIndex(hcl2['Date']))
print("Candlestick graph for HCL")
fig2 = go.Figure(data=[go.Candlestick(x=hcl2.index,
                open=hcl['Open'],
                high=hcl['High'],
                low=hcl['Low'],
                close=hcl['Close'],
                increasing_line_color='green',
                decreasing_line_color='red')])
fig2.show()
# Out:
# Candlestick graph for HCL
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# CANDLESTICK GRAPH FOR TCS

# %%
tcsdf2=tcsdf2.set_index(pd.DatetimeIndex(tcsdf2['Date']))
print("Candlestick graph for TCS")
fig2 = go.Figure(data=[go.Candlestick(x=tcsdf2.index,
                open=tcsdf['Open'],
                high=tcsdf['High'],
                low=tcsdf['Low'],
                close=tcsdf['Close'],
                increasing_line_color='green',
                decreasing_line_color='red')])
fig2.show()
# Out:
# Candlestick graph for TCS
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # ***SCATTER PLOT MATRIX FOR STOCKS***

# %% [markdown]
# Here we are using the function of pandas plotting scatter_matrix which helps us in plotting the scatter plot matrix for stocks and help us in comparing them and check if their is any relationship between the  opening cost of three stocks.

# %%
from pandas.plotting import scatter_matrix
data = pd.concat([drrdy['Open'],hcl['Open'],tcsdf['Open']],axis = 1)
data.columns = ['DRREDDY OPEN','HCLTECH OPEN','TCS OPEN']
scatter_matrix(data, figsize = (8,8), hist_kwds= {'bins':250})
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc91b472150>,
# ...
#       dtype=object)

# %% [markdown]
# # ***VOLATILITY***

# %%
drrdy['returns']=""
hcl['returns']=""
tcsdf['returns']=""
drrdy['returns'] = (drrdy['Close']/drrdy['Close'].shift(1)) -1
hcl['returns'] = (hcl['Close']/hcl['Close'].shift(1))-1
tcsdf['returns'] = (tcsdf['Close']/tcsdf['Close'].shift(1)) - 1
drrdy['returns'].hist(bins = 100, label = 'DRREDDY', alpha = 0.5, figsize = (15,7))
hcl['returns'].hist(bins = 100, label = 'HCLTECH', alpha = 0.5)
tcsdf['returns'].hist(bins = 100, label = 'TCS', alpha = 0.5)
plt.legend()
#volatility

# %% [markdown]
# **ANS:** From the graph plotted above it is clearly visible that DRREDDY stocks are the most volatile stocks.

# %%
m1 = drrdy['returns'].mean()
m2 = hcl['returns'].mean()
m3 = tcsdf['returns'].mean()
mx = (m1 if (m1 > m2 and m1 > m3) else
     (m2 if (m2 > m1 and m2 > m3) else m3))
if mx == m1:
  print('DRREDDY is the stock which has given best returns')
if mx == m2:
  print("HCLTECH is the stock which has given best returns")
if mx == m3:
  print("TCS is the stock which has given best returns")
# Out:
# TCS is the stock which has given best returns

# %%
pip install deep-forest
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.5 MB 7.8 MB/s
# ...

# %% [markdown]
# # ***Prediction***

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=20,10
from keras.models import Sequential
from keras.layers import LSTM,Dropout,Dense


from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv("TCS.csv", index_col=1)
df.head()
# Out:
#               Date Series  Prev Close    Open    High     Low    Last   Close  \
# Symbol
# TCS     2004-08-25     EQ      850.00  1198.7  1198.7  979.00  985.00  987.95
# TCS     2004-08-26     EQ      987.95   992.0   997.0  975.30  976.85  979.00
# TCS     2004-08-27     EQ      979.00   982.4   982.4  958.55  961.20  962.65
# TCS     2004-08-30     EQ      962.65   969.9   990.0  965.00  986.40  986.75
# TCS     2004-08-31     EQ      986.75   986.5   990.0  976.00  987.80  988.10
#
#            VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Symbol
# TCS     1008.32  17116372  1.725876e+15     NaN             5206360
# TCS      985.65   5055400  4.982865e+14     NaN             1294899
# TCS      969.94   3830750  3.715586e+14     NaN              976527
# TCS      982.65   3058151  3.005106e+14     NaN              701664
# TCS      982.18   2649332  2.602133e+14     NaN              695234
#
#         %Deliverble
# Symbol
# TCS          0.3042
# ...

# %%
df["Date"]=pd.to_datetime(df.Date,format="%Y-%m-%d")
df.index=df['Date']

plt.figure(figsize=(16,8))
plt.plot(df["Close"],label='Close Price history')

# %%
data=df.sort_index(ascending=True,axis=0)
new_dataset=pd.DataFrame(index=range(0,len(df)),columns=['Date','Close'])
new_dataset  = data[['Date', 'Close']]

# %%
scaler=MinMaxScaler(feature_range=(0,1))
new_dataset.index=new_dataset.Date
new_dataset.drop('Date',axis=1,inplace=True)
final_dataset=new_dataset.values

train_data=final_dataset[0:987,:]
valid_data=final_dataset[987:,:]

scaled_data=scaler.fit_transform(final_dataset)



x_train_data,y_train_data=[],[]

for i in range(60,len(train_data)):
    x_train_data.append(scaled_data[i-60:i,0])
    y_train_data.append(scaled_data[i,0])
    
x_train_data,y_train_data=np.array(x_train_data),np.array(y_train_data)

x_train_data=np.reshape(x_train_data,(x_train_data.shape[0],x_train_data.shape[1],1))
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
lstm_model=Sequential()
lstm_model.add(LSTM(units=50,return_sequences=True,input_shape=(x_train_data.shape[1],1)))
lstm_model.add(LSTM(units=50))
lstm_model.add(Dense(1))

inputs_data=new_dataset[len(new_dataset)-len(valid_data)-60:].values
inputs_data=inputs_data.reshape(-1,1)
inputs_data=scaler.transform(inputs_data)

lstm_model.compile(loss='mean_squared_error',optimizer='adam')
lstm_model.fit(x_train_data,y_train_data,epochs=1,batch_size=1,verbose=2)
# Out:
# 927/927 - 38s - loss: 0.0013 - 38s/epoch - 41ms/step

# %%
X_test=[]
for i in range(60,inputs_data.shape[0]):
    X_test.append(inputs_data[i-60:i,0])
X_test=np.array(X_test)

X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
predicted_closing_price=lstm_model.predict(X_test)
predicted_closing_price=scaler.inverse_transform(predicted_closing_price)
# Out:
# 99/99 [==============================] - 2s 15ms/step

# %%
lstm_model.save("saved_model.h5")

# %%
train_data=new_dataset[:987]
valid_data=new_dataset[987:]
valid_data['Predictions']=predicted_closing_price
plt.plot(train_data["Close"])
plt.plot(valid_data[['Close',"Predictions"]])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# # ***REFERENCES***

# %% [markdown]
# **References:**
#
#
# 1.  [https://plotly.com/python/graph-objects/](https://)
# 2.  [https://matplotlib.org/](https://)
# 3.  [https://www.kaggle.com/rohanrao/nifty50-stock-market-data](https://)
